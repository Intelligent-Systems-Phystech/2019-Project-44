# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from matplotlib import lines
import utils as ut
import m_models as mm
import os
from tqdm import tqdm_notebook as tqdm

import pylab

import statsmodels.api as sm

import scipy.stats as sps
from scipy.optimize import minimize_scalar as minimize_scalar

import pickle

from sklearn.linear_model import Lasso

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 12
plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams['legend.fontsize'] = 40
plt.rcParams['axes.titlesize']= 36
plt.rcParams['axes.labelsize']= 40
plt.rcParams['figure.figsize'] = (24.0, 12.0)
plt.rcParams['font.size'] = 40

# %% [markdown]
# ---

# %%
N = 10
M = 1000
sigma = 1

bootstrap_num_iter = 1000

# %% [markdown]
# ---
# Генерируем выборку

# %%
w = sps.uniform().rvs(N)

X = sps.norm(loc=0, scale=1).rvs(size=(M, N))
y = X @ w + sps.norm(loc=0, scale=sigma).rvs(size=M)

# %%
m_0 = 100
W = []
W_std = []

alphas = np.arange(0.01, 2, 0.01)

for alpha in tqdm(alphas):
    
    w_hats = []
    
    for i in range(bootstrap_num_iter):
        
        idx = np.random.choice(M, size=m_0)
        
        X_cur = X[idx]
        y_cur = y[idx]
        
        cur_model = Lasso(alpha=alpha)
        cur_model.fit(X_cur, y_cur)
        w_hats.append(cur_model.coef_)
    
    W.append(np.mean(w_hats, axis=0))
    W_std.append(np.std(w_hats, axis=0))
    
W = np.asarray(W)
W_std = np.asarray(W_std)

for i in range(N):
    plt.plot(alphas, W[:, i], label='$w_{' + str(i) + '}$')
    plt.fill_between(alphas, sps.norm(loc=W[:, i], scale=W_std[:, i]).ppf(0.05), sps.norm(loc=W[:, i], scale=W_std[:, i]).ppf(0.95),
                 alpha=0.1)

plt.xlabel('$\\tau$')
plt.legend()
plt.grid()
# plt.savefig('../data/pics/synthetic_lasso_W.pdf', format='pdf')
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=199), HTML(value='')))
# /home/coder/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2003: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/coder/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2004: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %% [markdown]
# ---
# Запомним те $\alpha$, при которых обнуляется очередной коэффициент

# %%
alpha_threshold = []

for i in range(N):
    alpha_threshold.append((alphas[np.argmax(W[:, i] < 0.05)], i))
    
alpha_threshold = sorted(alpha_threshold)
alpha_threshold = np.asarray([[t[0], t[1]] for t in alpha_threshold])

# %% [markdown]
# ---
# Построим зависимость функции ошибки от объема выборки при разном количестве признаков

# %%
S = []
std = []

test_size = 50

for j in tqdm(range(N)):

    S_cur = []
    std_cur = []
    
    X_j = X[:, alpha_threshold[:j + 1, 1].astype(np.int32)]
    y_j = y

    for m_0 in range(10, M - test_size):

        mse = []

        for i in range(bootstrap_num_iter):

            idx = np.random.choice(M, size=m_0 + test_size, replace=False)

            X_cur = X_j[idx]
            y_cur = y_j[idx]
            
            X_train = X_cur[:-test_size]
            y_train = y_cur[:-test_size]
            X_test = X_cur[-test_size:]
            y_test = y_cur[-test_size:]

            w_hat = ut.get_params(X_train, y_train)
#             mse.append(np.mean((X_test @ w_hat - y_test) ** 2))
            mse.append(np.exp(-np.mean((X_test @ w_hat - y_test) ** 2)))

        S_cur.append(np.mean(mse))
        std_cur.append(np.std(mse))

    S_cur = np.asarray(S_cur)
    std_cur = np.asarray(std_cur)
    
    S.append(S_cur)
    std.append(std_cur)

    plt.plot(np.arange(10, M - test_size), S[j], label='n = {}'.format(j + 1) + '; $\\tau$ = {}'.format(round(alpha_threshold[j, 0], 2)))
    plt.fill_between(np.arange(10, M - test_size), sps.norm(loc=S[j], scale=std[j]).ppf(0.05), sps.norm(loc=S[j], scale=std[j]).ppf(0.95),
                     alpha=0.2)
    
S = np.asarray(S)
std = np.asarray(std)

plt.xlabel('объем выборки, m')
plt.ylabel('$e^{-MSE(\mathbf{x}, y, \hat{\mathbf{w}})}$')
plt.legend(loc='lower right')
plt.grid()
    
# plt.savefig('../data/pics/synthetic_MSE_n.pdf', format='pdf')

plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))

# %%
X_axis = np.arange(N)
Y_axis = np.arange(20, M - test_size)
XX, YY = np.meshgrid(X_axis, Y_axis)
ZZ = S[:, 10:].T
ZZ_down = sps.norm(loc=S[:, 10:].T, scale=std[:, 10:].T).ppf(0.05)
ZZ_up = sps.norm(loc=S[:, 10:].T, scale=std[:, 10:].T).ppf(0.95)

# %%
fig = plt.figure(figsize=(30, 16))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(XX, YY, ZZ, rcount=500, ccount=500)
# ax.plot_surface(XX, YY, ZZ_down, cmap=cm.Reds, alpha=0.3, rcount=500, ccount=500)
# ax.plot_surface(XX, YY, ZZ_up, cmap=cm.Reds, alpha=0.3, rcount=500, ccount=500)
plt.xlabel('количество признаков', labelpad=50)
plt.ylabel('объём выборки', labelpad=50)

label_mean = lines.Line2D([0],[0], linestyle="none", c='b', marker = 'o')
# label_interval = lines.Line2D([0],[0], linestyle="none", c='r', marker = 'o')
ax.legend([label_mean], ['$\mathsf{E}e^{-MSE(\\mathbf{x}, y, \\hat{\\mathbf{w}})}$'], numpoints = 1)
# plt.savefig('../data/pics/synthetic_MSE_surface.pdf', format='pdf')

# %%
fig = plt.figure(figsize=(30, 16))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(XX, YY, std[:, 10:].T, rcount=500, ccount=500)
plt.xlabel('количество признаков', labelpad=50)
plt.ylabel('объём выборки', labelpad=50)

label_mean = lines.Line2D([0],[0], linestyle="none", c='b', marker = 'o')
ax.legend([label_mean], ['$\mathsf{D}e^{-MSE(\\mathbf{x}, y, \\hat{\\mathbf{w}})}$'], numpoints = 1)
# plt.savefig('../data/pics/synthetic_MSE_std_surface.pdf', format='pdf')

# %%
W = []

for j in tqdm(range(N)):

    X_j = X[:, alpha_threshold[:j + 1, 1].astype(np.int32)]
    y_j = y
    
    cov = []

    for m in tqdm(range(10, M)):
    
        W_cur = []

        for i in range(bootstrap_num_iter):
            idx = np.random.choice(M, size=m, replace=False)

            X_m = X_j[idx]
            y_m = y_j[idx]
            
            statmodel = ut.define_model(y_m)
            
            w_hat_j = ut.get_params(X_m, y_m)
            w_hat = np.zeros(N)
            for num, idx in enumerate(alpha_threshold[:j + 1, 1].astype(np.int32)):
                w_hat[idx] = w_hat_j[num]
            
            w_hat.resize((1, N))
            W_cur.append(w_hat)

        W_cur = np.asarray(W_cur)
        
        cur_cov = np.zeros((N, N))
    
        for i in range(bootstrap_num_iter):
            cur_cov += W_cur[i].T @ W_cur[i]
        
        cov.append(cur_cov / (bootstrap_num_iter - 1))
        
    cov = np.asarray(cov)
        
    W.append(cov)
    
W = np.asarray(W)
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))

# %%
for i in range(N):
    for j in range(i + 1, N):
        plt.plot(np.arange(1, N + 1), W[:, 100, i, j], alpha=0.5, label='$cov_m(w_{}, w_{})$'.format(i, j))
        
plt.grid()
plt.xlabel('число признаков, n')
plt.ylabel('$\hat{A}_{ij}$')
plt.savefig('../data/pics/synthetic_W_from_N.pdf', format='pdf')
plt.show()

# %% [markdown]
# ---
# То же самое, от $\tau$.

# %%
from sklearn.linear_model import Lasso

W = []

alphas = np.arange(0.01, 2, 0.03)

for alpha in tqdm(alphas):

    cov = []

    for m in tqdm(range(10, M)):
    
        W_cur = []

        for i in range(bootstrap_num_iter):
            idx = np.random.choice(M, size=m, replace=False)

            X_m = X[idx]
            y_m = y[idx]
            
            lm = Lasso(alpha=alpha)
            
            lm.fit(X_m, y_m)
            
            w_hat = lm.coef_
            W_cur.append(w_hat)

        W_cur = np.asarray(W_cur)
        
        cur_cov = np.zeros((N, N))
    
        for i in range(bootstrap_num_iter):
            cur_cov += W_cur[i].T @ W_cur[i]
        
        cov.append(cur_cov / (bootstrap_num_iter - 1))
        
    cov = np.asarray(cov)
        
    W.append(cov)
    
W = np.asarray(W)
# Out:
# HBox(children=(IntProgress(value=0, max=67), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02535606702975035, tolerance: 0.0024254285910721356
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017696019752846404, tolerance: 0.0037657199014107636
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015603084217380658, tolerance: 0.0042705324196117235
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0029888967601517102, tolerance: 0.002537450130983234
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017413815925113152, tolerance: 0.005133117285709157
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009929947970814756, tolerance: 0.0020624889814048987
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01021203738450055, tolerance: 0.004148912957605678
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010094651221155326, tolerance: 0.0024036075043726676
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012568942060883437, tolerance: 0.0015530088090667474
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00461748547616847, tolerance: 0.0014428038984810646
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005316947706303088, tolerance: 0.0019182259167709124
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00848709700955208, tolerance: 0.003945506779438238
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02772426740878775, tolerance: 0.005424676650595618
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037895375148756377, tolerance: 0.002044562235424361
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006871900825713595, tolerance: 0.0013839567534196524
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0033416000754339648, tolerance: 0.002324837790757006
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008629898550746383, tolerance: 0.002842437089459233
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07069304142610044, tolerance: 0.0023982427345602972
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005537586551937496, tolerance: 0.0022264703904691973
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003809769210183639, tolerance: 0.0015127987697533133
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007508656025094415, tolerance: 0.004322898917032391
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006634345553982929, tolerance: 0.002956830848250343
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11838692090764391, tolerance: 0.0026845913591579526
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018823232297008996, tolerance: 0.003937163805603064
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0775432693046959, tolerance: 0.0044984735365842035
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016419178637919196, tolerance: 0.0035372957771714875
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017891466340086648, tolerance: 0.004791458352470218
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02646871921299955, tolerance: 0.006849814955868635
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004977699937669833, tolerance: 0.0025146813806982307
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0026354540065671728, tolerance: 0.0014538294604679537
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04446444127471172, tolerance: 0.00427106092189567
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02083135224275999, tolerance: 0.005261359746148279
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00639604695701701, tolerance: 0.0039784968544010245
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009291386981689964, tolerance: 0.003167566933260544
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014578753523913912, tolerance: 0.0007195933618290853
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024209534473015104, tolerance: 0.004383697219679099
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013767878617588547, tolerance: 0.003612091511798248
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007986943809857927, tolerance: 0.002236864636481603
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01831481123948331, tolerance: 0.003391760635780195
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0031163487603751427, tolerance: 0.002905290970424328
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010766137025908507, tolerance: 0.004342758190131789
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008718752607443925, tolerance: 0.003699613836382242
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007453155252925114, tolerance: 0.0036761544297472756
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023759861949288863, tolerance: 0.005307766391985571
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021698825891736107, tolerance: 0.0035007952553550797
#   positive)
# HBox(children=(IntProgress(value=0, max=990), HTML(value='')))
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0059671686572904115, tolerance: 0.004859178791590212
#   positive)
# /home/coder/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0032932522869310032, tolerance: 0.002129979646158899
#   positive)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-ad19b93478f3> in <module>
#      14
#      15         for i in range(bootstrap_num_iter):
# ---> 16             idx = np.random.choice(M, size=m, replace=False)
#      17
#      18             X_m = X[idx]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.permutation()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.shuffle()
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_internal.py in __init__(self, array, ptr)
#     295             self._ctypes = ctypes
#     296             # get a void pointer to the buffer, which keeps the array alive
# --> 297             self._data = _get_void_ptr(array)
#     298             assert self._data.value == ptr
#     299         else:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_internal.py in _get_void_ptr(arr)
#     272
#     273
# --> 274 def _get_void_ptr(arr):
#     275     """
#     276     Get a `ctypes.c_void_p` to arr.data, that keeps a reference to the array
#
# KeyboardInterrupt:
